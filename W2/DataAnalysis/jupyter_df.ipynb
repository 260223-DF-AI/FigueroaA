# %%
import pandas as pd

# %%
df = pd.read_csv('starter_code/orders.csv')

# %%
print(df.head())
for value in df['order_date']:
    print(value)
    date_list = value.split('-')
    value = date_list[1:-1:]
    print(date_list[0])
# Out:
#    order_id customer_id  order_date    product_name     category  quantity  \
# 0      1001        C001  2024-01-05      Laptop Pro  Electronics         1
# 1      1002        C002  2024-01-05  Wireless Mouse  Electronics         2
# 2      1003        C001  2024-01-06       USB Cable  Accessories         3
#
#    unit_price region
# 0     1299.99  North
# 1       29.99  South
# 2        9.99  North
# 2024-01-05
# ['01']
# 2024-01-05
# ['01']
# 2024-01-06
# ['01']
